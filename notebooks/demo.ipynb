# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2
#dont forget to restart the kernal

# %%
# You can double-check your Python path like this...
import sys  
sys.path.append('c:\\Users\\Jiyan\\OneDrive\\OXFORD\\Year3\\B1_Engineering Computing\\practical\\uuv_mission')
sys.path.append('c:\\Users\\Jiyan\\OneDrive\\OXFORD\\Year3\\B1_Engineering Computing\\practical\\data')
print(sys.path)
# Out:
# ['c:\\Users\\Jiyan\\OneDrive\\OXFORD\\Year3\\B1_Engineering Computing\\practical\\notebooks', 'c:\\ProgramData\\anaconda3\\python311.zip', 'c:\\ProgramData\\anaconda3\\DLLs', 'c:\\ProgramData\\anaconda3\\Lib', 'c:\\ProgramData\\anaconda3', '', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\Jiyan\\OneDrive\\OXFORD\\Year3\\B1_Engineering Computing\\practical\\uuv_mission', 'c:\\Users\\Jiyan\\OneDrive\\OXFORD\\Year3\\B1_Engineering Computing\\practical\\data']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from control import PDController
from dynamic import Submarine, ClosedLoop, Mission

sub = Submarine()
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, PDController)
mission = Mission.from_csv("mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)

# %%
len(mission.reference)
# Out:
# 100
